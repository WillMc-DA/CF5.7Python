# %% [markdown]
# ### This script contains:
#
# #### 1. Import libraries & dataframes
# #### 2. Confirming the Shape, Head and Info of the 2 data sets
# #### 3. Cleaning up superfluous columns in the datasets
# #### 4. Merging the datasets
# #### 5. Exporting data

# %% [markdown]
# ## Importing libraries and datasets

# %%
#Import libraries 
import pandas as pd
import numpy as np
import os

# %%
#Folder path into usable string
path = r'C:\Users\willm\Instacart Basket Analysis'

# %%
#Import Orders_products_combined Dataset
orders_products_combined = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_combined.pkl'))

# %%
#Import Cleaned Products Dataset
df_prods_checked = pd.read_csv(os.path.join(path, '02 Data', 'Prepared Data', 'products_checked.csv'))

# %% [markdown]
# ### Confirming the Shape, Head and Info of the 2 data sets

# %%
orders_products_combined.shape
# Out:
# (32434489, 13)

# %% [markdown]
# #### 32,434,489 is the same ammount of entries I exported in the last script

# %%
orders_products_combined.head(70)
# Out:
#     Unnamed: 0  Unnamed: 0.1 order_id  user_id  order_number  \
# 0            0             0  2539329        1             1
# 1            0             0  2539329        1             1
# 2            0             0  2539329        1             1
# 3            0             0  2539329        1             1
# 4            0             0  2539329        1             1
# ..         ...           ...      ...      ...           ...
# 65          11            11  2168274        2             1
# 66          11            11  2168274        2             1
# 67          11            11  2168274        2             1
# 68          11            11  2168274        2             1
# 69          11            11  2168274        2             1
#
#     orders_day_of_week  order_hour_of_day  days_since_prior_order  \
# 0                    2                  8                     NaN
# 1                    2                  8                     NaN
# ...

# %%
df_prods_checked.head()
# Out:
#    Unnamed: 0  product_id                                       product_name  \
# 0           0           1                         Chocolate Sandwich Cookies
# 1           1           2                                   All-Seasons Salt
# 2           2           3               Robust Golden Unsweetened Oolong Tea
# 3           3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...
# 4           4           5                          Green Chile Anytime Sauce
#
#    aisle_id  department_id  prices
# 0        61             19     5.8
# 1       104             13     9.3
# 2        94              7     4.5
# 3        38              1    10.5
# 4         5             13     4.3

# %%
df_prods_checked.shape
# Out:
# (49672, 6)

# %%
df_prods_checked.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49672 entries, 0 to 49671
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Unnamed: 0     49672 non-null  int64
#  1   product_id     49672 non-null  int64
#  2   product_name   49672 non-null  object
#  3   aisle_id       49672 non-null  int64
#  4   department_id  49672 non-null  int64
#  5   prices         49672 non-null  float64
# dtypes: float64(1), int64(4), object(1)
# memory usage: 2.3+ MB

# %%
orders_products_combined.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 32434489 entries, 0 to 32434488
# Data columns (total 13 columns):
#  #   Column                  Dtype
# ---  ------                  -----
#  0   Unnamed: 0              int64
#  1   Unnamed: 0.1            int64
#  2   order_id                object
#  3   user_id                 int64
#  4   order_number            int64
#  5   orders_day_of_week      int64
#  6   order_hour_of_day       int64
#  7   days_since_prior_order  float64
#  8   first_order             object
#  9   product_id              int64
#  10  add_to_cart_order       int64
#  11  reordered               int64
#  12  _merge                  category
# dtypes: category(1), float64(1), int64(9), object(2)
# memory usage: 3.2+ GB

# %% [markdown]
# #### Both product_id columns are data type int64

# %% [markdown]
# ### Cleaning up superfluous columns in the datasets

# %%
#_merge is being removed so the next merge can use that column name.
orders_products_combined = orders_products_combined.drop(columns = ['Unnamed: 0', 'Unnamed: 0.1', '_merge'])

# %%
orders_products_combined.head(70)
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2539329        1             1                   2                  8
# 2   2539329        1             1                   2                  8
# 3   2539329        1             1                   2                  8
# 4   2539329        1             1                   2                  8
# ..      ...      ...           ...                 ...                ...
# 65  2168274        2             1                   2                 11
# 66  2168274        2             1                   2                 11
# 67  2168274        2             1                   2                 11
# 68  2168274        2             1                   2                 11
# 69  2168274        2             1                   2                 11
#
#     days_since_prior_order  first_order  product_id  add_to_cart_order  \
# ...

# %%
df_prods_checked = df_prods_checked.drop(columns = ['Unnamed: 0',])

# %%
df_prods_checked.head()
# Out:
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
#
#    department_id  prices
# 0             19     5.8
# 1             13     9.3
# 2              7     4.5
# 3              1    10.5
# 4             13     4.3

# %% [markdown]
# ### Merging the 2 data sets

# %%
#Merging, using the product_id column
df_merge_orders2 = orders_products_combined.merge(df_prods_checked, on = 'product_id', indicator = True)

# %%
df_merge_orders2.head(70)
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2398795        1             2                   3                  7
# 2    473747        1             3                   3                 12
# 3   2254736        1             4                   4                  7
# 4    431534        1             5                   4                 15
# ..      ...      ...           ...                 ...                ...
# 65   147262       82            18                   1                 13
# 66  3144004       82            19                   2                 15
# 67  2126069       98             3                   0                  9
# 68  2210120       98             7                   5                 14
# 69   681011       98             9                   3                  9
#
#     days_since_prior_order      first_order  product_id  add_to_cart_order  \
# ...

# %%
df_merge_orders2.shape
# Out:
# (32404859, 15)

# %%
df_merge_orders2['_merge'].value_counts()
# Out:
# both          32404859
# left_only            0
# right_only           0
# Name: _merge, dtype: int64

# %% [markdown]
# ## Exporting the file

# %%
#Exporting data to pkl
df_merge_orders2.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'orders_products_merged.pkl'))
