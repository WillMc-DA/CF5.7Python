# %% [markdown]
# ### This script contains:
#
# #### 1. Import libraries
# #### 2. Import dataframes
# #### 3. Finding missing values
# #### 4. Fixing missing values
# #### 5. Duplicates
# #### 6. Questions
# #### 7. Exporting data

# %% [markdown]
# ### Importing libraries

# %%
#Import libraries 
import pandas as pd
import numpy as np
import os

# %% [markdown]
# ### Importing Dataframes

# %%
#Folder path into usable string
path = r'C:\Users\willm\Instacart Basket Analysis'

# %%
#Import Products Dataset
df_prods = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'products.csv'))

# %%
#Import Orders_wrangled Dataset
df_ords = pd.read_csv(os.path.join(path, '02 Data', 'Prepared Data', 'orders_wrangled.csv'))

# %%
df_ords.head(30)
# Out:
#     Unnamed: 0  order_id  user_id  order_number  orders_day_of_week  \
# 0            0   2539329        1             1                   2
# 1            1   2398795        1             2                   3
# 2            2    473747        1             3                   3
# 3            3   2254736        1             4                   4
# 4            4    431534        1             5                   4
# 5            5   3367565        1             6                   2
# 6            6    550135        1             7                   1
# 7            7   3108588        1             8                   1
# 8            8   2295261        1             9                   1
# 9            9   2550362        1            10                   4
# 10          10   1187899        1            11                   4
# 11          11   2168274        2             1                   2
# 12          12   1501582        2             2                   5
# 13          13   1901567        2             3                   1
# 14          14    738281        2             4                   2
# 15          15   1673511        2             5                   3
# 16          16   1199898        2             6                   2
# 17          17   3194192        2             7                   2
# 18          18    788338        2             8                   1
# 19          19   1718559        2             9                   2
# 20          20   1447487        2            10                   1
# 21          21   1402090        2            11                   1
# 22          22   3186735        2            12                   1
# 23          23   3268552        2            13                   4
# 24          24    839880        2            14                   3
# 25          25   1492625        2            15                   1
# 26          26   1374495        3             1                   1
# 27          27    444309        3             2                   3
# 28          28   3002854        3             3                   3
# 29          29   2037211        3             4                   2
#
#     order_hour_of_day  days_since_prior_order
# 0                   8                     NaN
# 1                   7                    15.0
# 2                  12                    21.0
# 3                   7                    29.0
# 4                  15                    28.0
# 5                   7                    19.0
# 6                   9                    20.0
# 7                  14                    14.0
# 8                  16                     0.0
# 9                   8                    30.0
# 10                  8                    14.0
# 11                 11                     NaN
# 12                 10                    10.0
# 13                 10                     3.0
# 14                 10                     8.0
# 15                 11                     8.0
# 16                  9                    13.0
# 17                 12                    14.0
# 18                 15                    27.0
# 19                  9                     8.0
# 20                 11                     6.0
# 21                 10                    30.0
# 22                  9                    28.0
# 23                 11                    30.0
# 24                 10                    13.0
# 25                 11                    30.0
# 26                 14                     NaN
# 27                 19                     9.0
# 28                 16                    21.0
# 29                 18                    20.0

# %% [markdown]
# ### Finding missing values

# %%
#Finding which columns having missing data, and how many times
df_prods.isnull().sum()
# Out:
# product_id        0
# product_name     16
# aisle_id          0
# department_id     0
# prices            0
# dtype: int64

# %% [markdown]
# ### Fixing missing values

# %%
#Creating a subset with the missing values
df_nan = df_prods[df_prods['product_name'].isnull() == True]

# %%
df_nan
# Out:
#        product_id product_name  aisle_id  department_id  prices
# 33             34          NaN       121             14    12.2
# 68             69          NaN        26              7    11.8
# 115           116          NaN        93              3    10.8
# 261           262          NaN       110             13    12.1
# 525           525          NaN       109             11     1.2
# 1511         1511          NaN        84             16    14.3
# 1780         1780          NaN       126             11    12.3
# 2240         2240          NaN        52              1    14.2
# 2586         2586          NaN       104             13    12.4
# 3159         3159          NaN       126             11    13.1
# 3230         3230          NaN       120             16    14.4
# 3736         3736          NaN        41              8    14.8
# 4283         4283          NaN        77              7    14.4
# 4790         4790          NaN        91             16    14.5
# 38187       38183          NaN        39             12    20.9
# 40444       40440          NaN       120             16    14.8

# %%
df_prods.shape
# Out:
# (49693, 5)

# %%
#Creating a new data frame with only the clean data
df_prods_clean = df_prods[df_prods['product_name'].isnull() == False]

# %%
df_prods_clean.shape
# Out:
# (49677, 5)

# %% [markdown]
# ### Duplicates

# %%
df_dups = df_prods_clean[df_prods_clean.duplicated()]

# %%
df_dups
# Out:
#        product_id                                       product_name  \
# 462           462                  Fiber 4g Gummy Dietary Supplement
# 18459       18458                                         Ranger IPA
# 26810       26808               Black House Coffee Roasty Stout Beer
# 35309       35306  Gluten Free Organic Peanut Butter & Chocolate ...
# 35495       35491                            Adore Forever Body Wash
#
#        aisle_id  department_id  prices
# 462          70             11     4.8
# 18459        27              5     9.2
# 26810        27              5    13.4
# 35309       121             14     6.8
# 35495       127             11     9.9

# %%
#Droping the duplicates
df_prods_clean_no_dups = df_prods_clean.drop_duplicates()

# %%
df_prods_clean_no_dups.shape
# Out:
# (49672, 5)

# %%
df_prods_clean_no_dups.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 49672 entries, 0 to 49692
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   product_id     49672 non-null  int64
#  1   product_name   49672 non-null  object
#  2   aisle_id       49672 non-null  int64
#  3   department_id  49672 non-null  int64
#  4   prices         49672 non-null  float64
# dtypes: float64(1), int64(3), object(1)
# memory usage: 2.3+ MB

# %% [markdown]
# ### Questions

# %%
#Are there any missing values in the df_ords dataframe?

# %%
df_ords.isnull().sum()
# Out:
# Unnamed: 0                     0
# order_id                       0
# user_id                        0
# order_number                   0
# orders_day_of_week             0
# order_hour_of_day              0
# days_since_prior_order    206209
# dtype: int64

# %% [markdown]
# #### There are 206,209 orders that show NaN in the days_since_prior_order. Seen as NaN is different to 0.0 - which would imply something was ordered today - these NaN entries should be from people who have only made 1 order from the company - using that customer profile.

# %%
#How do we mark these specific orders out?

# %% [markdown]
# #### Create a new variable that acts like a flag - we can have it show 'First Order' which the marketting team can filter for, for easier targetting.

# %%
df_ords['first_order'] = np.where(np.isnan(df_ords['days_since_prior_order'].values), 'First Order', 'Repeat Customer')

# %%
df_ords.head(30)
# Out:
#     Unnamed: 0  order_id  user_id  order_number  orders_day_of_week  \
# 0            0   2539329        1             1                   2
# 1            1   2398795        1             2                   3
# 2            2    473747        1             3                   3
# 3            3   2254736        1             4                   4
# 4            4    431534        1             5                   4
# 5            5   3367565        1             6                   2
# 6            6    550135        1             7                   1
# 7            7   3108588        1             8                   1
# 8            8   2295261        1             9                   1
# 9            9   2550362        1            10                   4
# 10          10   1187899        1            11                   4
# 11          11   2168274        2             1                   2
# 12          12   1501582        2             2                   5
# 13          13   1901567        2             3                   1
# 14          14    738281        2             4                   2
# 15          15   1673511        2             5                   3
# 16          16   1199898        2             6                   2
# 17          17   3194192        2             7                   2
# 18          18    788338        2             8                   1
# 19          19   1718559        2             9                   2
# 20          20   1447487        2            10                   1
# 21          21   1402090        2            11                   1
# 22          22   3186735        2            12                   1
# 23          23   3268552        2            13                   4
# 24          24    839880        2            14                   3
# 25          25   1492625        2            15                   1
# 26          26   1374495        3             1                   1
# 27          27    444309        3             2                   3
# 28          28   3002854        3             3                   3
# 29          29   2037211        3             4                   2
#
#     order_hour_of_day  days_since_prior_order      first_order
# 0                   8                     NaN      First Order
# 1                   7                    15.0  Repeat Customer
# 2                  12                    21.0  Repeat Customer
# 3                   7                    29.0  Repeat Customer
# 4                  15                    28.0  Repeat Customer
# 5                   7                    19.0  Repeat Customer
# 6                   9                    20.0  Repeat Customer
# 7                  14                    14.0  Repeat Customer
# 8                  16                     0.0  Repeat Customer
# 9                   8                    30.0  Repeat Customer
# 10                  8                    14.0  Repeat Customer
# 11                 11                     NaN      First Order
# 12                 10                    10.0  Repeat Customer
# 13                 10                     3.0  Repeat Customer
# 14                 10                     8.0  Repeat Customer
# 15                 11                     8.0  Repeat Customer
# 16                  9                    13.0  Repeat Customer
# 17                 12                    14.0  Repeat Customer
# 18                 15                    27.0  Repeat Customer
# 19                  9                     8.0  Repeat Customer
# 20                 11                     6.0  Repeat Customer
# 21                 10                    30.0  Repeat Customer
# 22                  9                    28.0  Repeat Customer
# 23                 11                    30.0  Repeat Customer
# 24                 10                    13.0  Repeat Customer
# 25                 11                    30.0  Repeat Customer
# 26                 14                     NaN      First Order
# 27                 19                     9.0  Repeat Customer
# 28                 16                    21.0  Repeat Customer
# 29                 18                    20.0  Repeat Customer

# %% [markdown]
# ### Exporting the Dataframes

# %%
#Exporting the clean data set
df_prods_clean_no_dups.to_csv(os.path.join(path, '02 Data','Prepared Data', 'products_checked.csv'))

# %%
#Exporting the Orders data set, with the new 'First Order' flag
df_ords.to_csv(os.path.join(path, '02 Data','Prepared Data', 'orders_with_first_order_flag.csv'))
