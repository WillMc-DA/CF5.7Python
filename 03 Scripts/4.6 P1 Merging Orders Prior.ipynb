# %% [markdown]
# ### This script contains:
#
# #### 1. Import libraries and datasets
# #### 2. Checking the Head, Shape and Info of the 2 datasets
# #### 3. Converting order_id columns to strings
# #### 4. Merging the data sets
# #### 5. Checking the merge
# #### 6. Exporting the merged data

# %% [markdown]
# ## 1. Importing libraries and datasets

# %%
#Import libraries 
import pandas as pd
import numpy as np
import os

# %%
#Folder path into usable string
path = r'C:\Users\willm\Instacart Basket Analysis'

# %%
#Import Orders_with_first_order_flag Dataset
df_ords = pd.read_csv(os.path.join(path, '02 Data', 'Prepared Data', 'orders_with_first_order_flag.csv'))

# %%
#Import order_products__prior Dataset
df_ords_prior = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'order_products__prior.csv'))

# %% [markdown]
# ## 2. Checking the Head, Shape and Info of the 2 datasets

# %%
df_ords_prior.head()
# Out:
#    order_id  product_id  add_to_cart_order  reordered
# 0         2       33120                  1          1
# 1         2       28985                  2          1
# 2         2        9327                  3          0
# 3         2       45918                  4          1
# 4         2       30035                  5          0

# %%
df_ords.head(30)
# Out:
#     Unnamed: 0  Unnamed: 0.1  order_id  user_id  order_number  \
# 0            0             0   2539329        1             1
# 1            1             1   2398795        1             2
# 2            2             2    473747        1             3
# 3            3             3   2254736        1             4
# 4            4             4    431534        1             5
# 5            5             5   3367565        1             6
# 6            6             6    550135        1             7
# 7            7             7   3108588        1             8
# 8            8             8   2295261        1             9
# 9            9             9   2550362        1            10
# 10          10            10   1187899        1            11
# 11          11            11   2168274        2             1
# 12          12            12   1501582        2             2
# 13          13            13   1901567        2             3
# ...

# %%
df_ords_prior.shape
# Out:
# (32434489, 4)

# %%
df_ords.shape
# Out:
# (3421083, 9)

# %%
df_ords.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3421083 entries, 0 to 3421082
# Data columns (total 9 columns):
#  #   Column                  Dtype
# ---  ------                  -----
#  0   Unnamed: 0              int64
#  1   Unnamed: 0.1            int64
#  2   order_id                int64
#  3   user_id                 int64
#  4   order_number            int64
#  5   orders_day_of_week      int64
#  6   order_hour_of_day       int64
#  7   days_since_prior_order  float64
#  8   first_order             object
# dtypes: float64(1), int64(7), object(1)
# memory usage: 234.9+ MB

# %% [markdown]
# ## 3. Converting order_id columns to strings to make merging use less computer memory

# %%
df_ords_prior['order_id'] = df_ords_prior['order_id'].astype('str')

# %%
df_ords['order_id'] = df_ords['order_id'].astype('str')

# %%
df_ords.head(30)
# Out:
#     Unnamed: 0  Unnamed: 0.1 order_id  user_id  order_number  \
# 0            0             0  2539329        1             1
# 1            1             1  2398795        1             2
# 2            2             2   473747        1             3
# 3            3             3  2254736        1             4
# 4            4             4   431534        1             5
# 5            5             5  3367565        1             6
# 6            6             6   550135        1             7
# 7            7             7  3108588        1             8
# 8            8             8  2295261        1             9
# 9            9             9  2550362        1            10
# 10          10            10  1187899        1            11
# 11          11            11  2168274        2             1
# 12          12            12  1501582        2             2
# 13          13            13  1901567        2             3
# ...

# %%
df_ords.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3421083 entries, 0 to 3421082
# Data columns (total 9 columns):
#  #   Column                  Dtype
# ---  ------                  -----
#  0   Unnamed: 0              int64
#  1   Unnamed: 0.1            int64
#  2   order_id                object
#  3   user_id                 int64
#  4   order_number            int64
#  5   orders_day_of_week      int64
#  6   order_hour_of_day       int64
#  7   days_since_prior_order  float64
#  8   first_order             object
# dtypes: float64(1), int64(6), object(2)
# memory usage: 234.9+ MB

# %% [markdown]
# ## 4. Merging the data sets

# %%
df_merged_large = df_ords.merge(df_ords_prior, on = 'order_id', indicator = True)

# %% [markdown]
# ## 5. Checking what the result was of the merge

# %%
df_merged_large.head(70)
# Out:
#     Unnamed: 0  Unnamed: 0.1 order_id  user_id  order_number  \
# 0            0             0  2539329        1             1
# 1            0             0  2539329        1             1
# 2            0             0  2539329        1             1
# 3            0             0  2539329        1             1
# 4            0             0  2539329        1             1
# ..         ...           ...      ...      ...           ...
# 65          11            11  2168274        2             1
# 66          11            11  2168274        2             1
# 67          11            11  2168274        2             1
# 68          11            11  2168274        2             1
# 69          11            11  2168274        2             1
#
#     orders_day_of_week  order_hour_of_day  days_since_prior_order  \
# 0                    2                  8                     NaN
# 1                    2                  8                     NaN
# ...

# %%
df_merged_large['_merge'].value_counts()

# %% [markdown]
# ## 6. Exporting the merged data to a Pickle File

# %%
#Exporting data to pkl

df_merged_large.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'orders_products_combined.pkl'))
